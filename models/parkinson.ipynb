# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %matplotlib inline

# %%
par_df=pd.read_csv("Parkinsson disease.csv")
par_df.tail(25)
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 170  phon_R01_S42_6      244.990       272.210       239.170         0.00451
# 171  phon_R01_S43_1      112.547       133.374       105.715         0.00355
# 172  phon_R01_S43_2      110.739       113.597       100.139         0.00356
# 173  phon_R01_S43_3      113.715       116.443        96.913         0.00349
# 174  phon_R01_S43_4      117.004       144.466        99.923         0.00353
# 175  phon_R01_S43_5      115.380       123.109       108.634         0.00332
# 176  phon_R01_S43_6      116.388       129.038       108.970         0.00346
# 177  phon_R01_S44_1      151.737       190.204       129.859         0.00314
# 178  phon_R01_S44_2      148.790       158.359       138.990         0.00309
# 179  phon_R01_S44_3      148.143       155.982       135.041         0.00392
# 180  phon_R01_S44_4      150.440       163.441       144.736         0.00396
# ...

# %%
par_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
par_df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
par_df=par_df.drop(columns='name',axis=1)

# %%
par_df.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
#sprating data and labels
x=par_df.drop(columns='status',axis=1)
y=par_df['status']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
y_train.value_counts()
# Out:
# status
# 1    118
# 0     38
# Name: count, dtype: int64

# %%
classifier = svm.SVC(
    kernel='linear',
    class_weight='balanced',
    probability=True,
    random_state=2
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(class_weight='balanced', kernel='linear', probability=True, random_state=2)

# %%
#accuracy score on the training data
x_train_prediction=classifier.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)
training_data_accuracy
# Out:
# 0.8525641025641025

# %%
x_test_prediction=classifier.predict(x_test)
testing_data_accuracy=accuracy_score(x_test_prediction,y_test)
testing_data_accuracy
# Out:
# 0.8205128205128205

# %%
par_df.tail(25)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 170      244.990       272.210       239.170         0.00451
# 171      112.547       133.374       105.715         0.00355
# 172      110.739       113.597       100.139         0.00356
# 173      113.715       116.443        96.913         0.00349
# 174      117.004       144.466        99.923         0.00353
# 175      115.380       123.109       108.634         0.00332
# 176      116.388       129.038       108.970         0.00346
# 177      151.737       190.204       129.859         0.00314
# 178      148.790       158.359       138.990         0.00309
# 179      148.143       155.982       135.041         0.00392
# 180      150.440       163.441       144.736         0.00396
# 181      148.462       161.078       141.998         0.00397
# 182      149.818       163.417       144.786         0.00336
# 183      117.226       123.925       106.656         0.00417
# ...

# %%
input_data = (244.990,272.210,239.170,0.00451,0.00002,0,0,0,0.00279,0.00237,0.00837,0.01897,0.03253,0.01049,21.528,0,0.522812,0.646818,-7.304500,0.171088,2.095237,0.096220)


input_data_as_numpy_array=np.asarray(input_data)
print(input_data_as_numpy_array)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped)

input_data_scaled = scaler.transform(input_data_reshaped)
prediction = classifier.predict(input_data_scaled)
print(prediction)

if(prediction[0] == 0):
    print("the person is not parkinson disease affected")
else:
    print("the person is parkinson disease affected")
# Out:
# [ 2.449900e+02  2.722100e+02  2.391700e+02  4.510000e-03  2.000000e-05
#   0.000000e+00  0.000000e+00  0.000000e+00  2.790000e-03  2.370000e-03
#   8.370000e-03  1.897000e-02  3.253000e-02  1.049000e-02  2.152800e+01
#   0.000000e+00  5.228120e-01  6.468180e-01 -7.304500e+00  1.710880e-01
#   2.095237e+00  9.622000e-02]
# [[ 2.449900e+02  2.722100e+02  2.391700e+02  4.510000e-03  2.000000e-05
#    0.000000e+00  0.000000e+00  0.000000e+00  2.790000e-03  2.370000e-03
#    8.370000e-03  1.897000e-02  3.253000e-02  1.049000e-02  2.152800e+01
#    0.000000e+00  5.228120e-01  6.468180e-01 -7.304500e+00  1.710880e-01
#    2.095237e+00  9.622000e-02]]
# [1]
# the person is parkinson disease affected
# C:\Users\Ali Ansari\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle
fileName="parpred.sav"
pickle.dump(classifier,open(fileName,'wb'))

# %%
loaded_model=pickle.load(open(fileName,'rb'))

# %%
input_data = (244.990,272.210,239.170,0.00451,0.00002,0,0,0,0.00279,0.00237,0.00837,0.01897,0.03253,0.01049,21.528,0,0.522812,0.646818,-7.304500,0.171088,2.095237,0.096220)


input_data_as_numpy_array=np.asarray(input_data)
print(input_data_as_numpy_array)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
print(input_data_reshaped)

input_data_scaled = scaler.transform(input_data_reshaped)
prediction = loaded_model.predict(input_data_scaled)
print(prediction)

if(prediction[0] == 0):
    print("the person is not heart disease affected")
else:
    print("the person is heart disease affected")
# Out:
# [ 2.449900e+02  2.722100e+02  2.391700e+02  4.510000e-03  2.000000e-05
#   0.000000e+00  0.000000e+00  0.000000e+00  2.790000e-03  2.370000e-03
#   8.370000e-03  1.897000e-02  3.253000e-02  1.049000e-02  2.152800e+01
#   0.000000e+00  5.228120e-01  6.468180e-01 -7.304500e+00  1.710880e-01
#   2.095237e+00  9.622000e-02]
# [[ 2.449900e+02  2.722100e+02  2.391700e+02  4.510000e-03  2.000000e-05
#    0.000000e+00  0.000000e+00  0.000000e+00  2.790000e-03  2.370000e-03
#    8.370000e-03  1.897000e-02  3.253000e-02  1.049000e-02  2.152800e+01
#    0.000000e+00  5.228120e-01  6.468180e-01 -7.304500e+00  1.710880e-01
#    2.095237e+00  9.622000e-02]]
# [1]
# the person is heart disease affected
# C:\Users\Ali Ansari\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
x.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...
